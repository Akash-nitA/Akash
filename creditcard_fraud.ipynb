# %% [markdown]
# <a href="https://colab.research.google.com/github/Akash-nitA/Akash-nitA/blob/main/creditcard_fraud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fetch Data and import necessary libraries

# %%
# !wget https://storage.googleapis.com/download.tensorflow.org/data/creditcard.csv
import numpy as np
import tensorflow as tf
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from keras import Sequential
from keras.layers import Dense,Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
# Out:
# --2022-02-07 18:33:46--  https://storage.googleapis.com/download.tensorflow.org/data/creditcard.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.15.128, 173.194.76.128, 64.233.167.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.15.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 150828752 (144M) [text/csv]
# Saving to: ‘creditcard.csv.1’
#
# creditcard.csv.1    100%[===================>] 143.84M   175MB/s    in 0.8s
#
# 2022-02-07 18:33:47 (175 MB/s) - ‘creditcard.csv.1’ saved [150828752/150828752]

# %%
data = pd.read_csv("creditcard.csv")

# %% [markdown]
# # Visualize the data

# %% [markdown]
# 1. plot a countplot to check for imbalance in the Dataset

# %%
plt.figure(figsize=(6,6))
sb.countplot(x="Class",data=data)
plt.show()

# %% [markdown]
# 2. check for skewness in the data. If skewness is present than we should apply necessary transfromations

# %%
plt.figure(figsize=(12,8))
variables = [x for x in data.columns]
Skewnesss =  data[variables].skew()
data.hist(bins=50, figsize=(18,25))
plt.show()

# %% [markdown]
# # Log Transformation

# %%
df = data.copy()
df['Amount'] = [0.001+x for x in data['Amount']]
df['Amount'] = np.log10(df['Amount'])
df = df.drop(['Time'], axis =1)

# %% [markdown]
# # Train Test Split

# %%
y=df['Class']
x=df.drop('Class',axis=1)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,shuffle=True)
x_test,x_validation,y_test,y_validation=train_test_split(x_test,y_test,test_size=0.2,shuffle=True)

# %% [markdown]
# # Standardize

# %%
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)
x_validation=sc.transform(x_validation)

# %% [markdown]
# # clipping the data

# %%
x_train=np.clip(x_train,-5,5)
x_test=np.clip(x_test,-5,5)
x_validation=np.clip(x_validation,-5,5)

# %% [markdown]
# # Seperate the dataset based on class

# %%
y_train=np.expand_dims(y_train,axis=1)
dataset=np.append(x_train,y_train,axis=1)
dataset=pd.DataFrame(dataset,columns=df.columns)
dataframe0=dataset[dataset['Class']==0]
dataframe1=dataset[dataset['Class']==1]

# %% [markdown]
# # joint plot

# %%
sb.jointplot(data=dataframe1,x="V1",y="V2",kind='hex')
plt.show()
sb.jointplot(data=dataframe0,x="V1",y="V2",kind='hex')
plt.show()

# %% [markdown]
# # Build model

# %%
metric=['AUC','Precision','Recall',
        'TruePositives','TrueNegatives',
        'FalsePositives','FalseNegatives','accuracy']

bias=np.log(dataframe1.shape[0]/dataframe0.shape[0])

def probitmodel():
  model=Sequential()
  model.add(Dense(8,activation='relu',input_shape=(29,),bias_initializer=tf.keras.initializers.Constant(bias)))
  model.add(Dropout(0.3))
  model.add(Dense(1,activation='sigmoid',kernel_regularizer='l2'))
  model.compile(loss='binary_crossentropy',optimizer='adam',metrics=metric)
  model.summary()
  return model

# %% [markdown]
# # Train the model

# %%
m=probitmodel()
callback=tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5,restore_best_weights=1)
m.evaluate(x_test[:10],y_test[:10])
history_0=m.fit(x_train,y_train,validation_data=[x_test,y_test],callbacks=callback,epochs=20)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 240
#
#  dropout (Dropout)           (None, 8)                 0
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 249
# Trainable params: 249
# Non-trainable params: 0
# _________________________________________________________________
# 1/1 [==============================] - 3s 3s/step - loss: 0.7073 - auc: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00 - true_positives: 0.0000e+00 - true_negatives: 10.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00 - accuracy: 1.0000
# Epoch 1/20
# 7121/7121 [==============================] - 81s 11ms/step - loss: 0.1539 - auc: 0.7350 - precision: 0.8526 - recall: 0.3359 - true_positives: 133.0000 - true_negatives: 227426.0000 - false_positives: 23.0000 - false_negatives: 263.0000 - accuracy: 0.9987 - val_loss: 0.0181 - val_auc: 0.9126 - val_precision: 0.8000 - val_recall: 0.3038 - val_true_positives: 24.0000 - val_true_negatives: 45484.0000 - val_false_positives: 6.0000 - val_false_negatives: 55.0000 - val_accuracy: 0.9987
# Epoch 2/20
# 7121/7121 [==============================] - 66s 9ms/step - loss: 0.0110 - auc: 0.7955 - precision: 0.8378 - recall: 0.3914 - true_positives: 155.0000 - true_negatives: 227419.0000 - false_positives: 30.0000 - false_negatives: 241.0000 - accuracy: 0.9988 - val_loss: 0.0059 - val_auc: 0.9302 - val_precision: 0.8333 - val_recall: 0.3165 - val_true_positives: 25.0000 - val_true_negatives: 45485.0000 - val_false_positives: 5.0000 - val_false_negatives: 54.0000 - val_accuracy: 0.9987
# Epoch 3/20
# 7121/7121 [==============================] - 65s 9ms/step - loss: 0.0070 - auc: 0.8091 - precision: 0.8704 - recall: 0.4747 - true_positives: 188.0000 - true_negatives: 227421.0000 - false_positives: 28.0000 - false_negatives: 208.0000 - accuracy: 0.9990 - val_loss: 0.0048 - val_auc: 0.9429 - val_precision: 0.8649 - val_recall: 0.4051 - val_true_positives: 32.0000 - val_true_negatives: 45485.0000 - val_false_positives: 5.0000 - val_false_negatives: 47.0000 - val_accuracy: 0.9989
# Epoch 4/20
# 7121/7121 [==============================] - 65s 9ms/step - loss: 0.0072 - auc: 0.7896 - precision: 0.8557 - recall: 0.4343 - true_positives: 172.0000 - true_negatives: 227420.0000 - false_positives: 29.0000 - false_negatives: 224.0000 - accuracy: 0.9989 - val_loss: 0.0052 - val_auc: 0.9429 - val_precision: 1.0000 - val_recall: 0.1266 - val_true_positives: 10.0000 - val_true_negatives: 45490.0000 - val_false_positives: 0.0000e+00 - val_false_negatives: 69.0000 - val_accuracy: 0.9985
# Epoch 5/20
# 7121/7121 [==============================] - 65s 9ms/step - loss: 0.0067 - auc: 0.8046 - precision: 0.8756 - recall: 0.4798 - true_positives: 190.0000 - true_negatives: 227422.0000 - false_positives: 27.0000 - false_negatives: 206.0000 - accuracy: 0.9990 - val_loss: 0.0047 - val_auc: 0.9429 - val_precision: 1.0000 - val_recall: 0.2405 - val_true_positives: 19.0000 - val_true_negatives: 45490.0000 - val_false_positives: 0.0000e+00 - val_false_negatives: 60.0000 - val_accuracy: 0.9987
# Epoch 6/20
# 7121/7121 [==============================] - 65s 9ms/step - loss: 0.0066 - auc: 0.7993 - precision: 0.9037 - recall: 0.4975 - true_positives: 197.0000 - true_negatives: 227428.0000 - false_positives: 21.0000 - false_negatives: 199.0000 - accuracy: 0.9990 - val_loss: 0.0045 - val_auc: 0.9428 - val_precision: 1.0000 - val_recall: 0.2658 - val_true_positives: 21.0000 - val_true_negatives: 45490.0000 - val_false_positives: 0.0000e+00 - val_false_negatives: 58.0000 - val_accuracy: 0.9987
# Epoch 7/20
# 7121/7121 [==============================] - 65s 9ms/step - loss: 0.0062 - auc: 0.8525 - precision: 0.8995 - recall: 0.4975 - true_positives: 197.0000 - true_negatives: 227427.0000 - false_positives: 22.0000 - false_negatives: 199.0000 - accuracy: 0.9990 - val_loss: 0.0039 - val_auc: 0.9429 - val_precision: 0.8333 - val_recall: 0.5696 - val_true_positives: 45.0000 - val_true_negatives: 45481.0000 - val_false_positives: 9.0000 - val_false_negatives: 34.0000 - val_accuracy: 0.9991
# Epoch 8/20
# 7121/7121 [==============================] - 65s 9ms/step - loss: 0.0058 - auc: 0.8780 - precision: 0.8841 - recall: 0.5202 - true_positives: 206.0000 - true_negatives: 227422.0000 - false_positives: 27.0000 - false_negatives: 190.0000 - accuracy: 0.9990 - val_loss: 0.0038 - val_auc: 0.9428 - val_precision: 0.8571 - val_recall: 0.7595 - val_true_positives: 60.0000 - val_true_negatives: 45480.0000 - val_false_positives: 10.0000 - val_false_negatives: 19.0000 - val_accuracy: 0.9994
# Epoch 9/20
# 7121/7121 [==============================] - 65s 9ms/step - loss: 0.0058 - auc: 0.8778 - precision: 0.8681 - recall: 0.5152 - true_positives: 204.0000 - true_negatives: 227418.0000 - false_positives: 31.0000 - false_negatives: 192.0000 - accuracy: 0.9990 - val_loss: 0.0036 - val_auc: 0.9429 - val_precision: 0.8776 - val_recall: 0.5443 - val_true_positives: 43.0000 - val_true_negatives: 45484.0000 - val_false_positives: 6.0000 - val_false_negatives: 36.0000 - val_accuracy: 0.9991
# Epoch 10/20
# 7121/7121 [==============================] - 65s 9ms/step - loss: 0.0054 - auc: 0.8843 - precision: 0.8750 - recall: 0.5303 - true_positives: 210.0000 - true_negatives: 227419.0000 - false_positives: 30.0000 - false_negatives: 186.0000 - accuracy: 0.9991 - val_loss: 0.0034 - val_auc: 0.9428 - val_precision: 0.8636 - val_recall: 0.7215 - val_true_positives: 57.0000 - val_true_negatives: 45481.0000 - val_false_positives: 9.0000 - val_false_negatives: 22.0000 - val_accuracy: 0.9993
# Epoch 11/20
# 7121/7121 [==============================] - 65s 9ms/step - loss: 0.0052 - auc: 0.8854 - precision: 0.8689 - recall: 0.5354 - true_positives: 212.0000 - true_negatives: 227417.0000 - false_positives: 32.0000 - false_negatives: 184.0000 - accuracy: 0.9991 - val_loss: 0.0034 - val_auc: 0.9490 - val_precision: 0.8667 - val_recall: 0.8228 - val_true_positives: 65.0000 - val_true_negatives: 45480.0000 - val_false_positives: 10.0000 - val_false_negatives: 14.0000 - val_accuracy: 0.9995
# Epoch 12/20
# 7121/7121 [==============================] - 65s 9ms/step - loss: 0.0056 - auc: 0.8741 - precision: 0.8653 - recall: 0.5354 - true_positives: 212.0000 - true_negatives: 227416.0000 - false_positives: 33.0000 - false_negatives: 184.0000 - accuracy: 0.9990 - val_loss: 0.0032 - val_auc: 0.9491 - val_precision: 0.8824 - val_recall: 0.7595 - val_true_positives: 60.0000 - val_true_negatives: 45482.0000 - val_false_positives: 8.0000 - val_false_negatives: 19.0000 - val_accuracy: 0.9994
# Epoch 13/20
# 7121/7121 [==============================] - 65s 9ms/step - loss: 0.0053 - auc: 0.8817 - precision: 0.8623 - recall: 0.5379 - true_positives: 213.0000 - true_negatives: 227415.0000 - false_positives: 34.0000 - false_negatives: 183.0000 - accuracy: 0.9990 - val_loss: 0.0032 - val_auc: 0.9428 - val_precision: 0.8667 - val_recall: 0.6582 - val_true_positives: 52.0000 - val_true_negatives: 45482.0000 - val_false_positives: 8.0000 - val_false_negatives: 27.0000 - val_accuracy: 0.9992
# Epoch 14/20
# 7121/7121 [==============================] - 63s 9ms/step - loss: 0.0052 - auc: 0.8904 - precision: 0.8629 - recall: 0.5404 - true_positives: 214.0000 - true_negatives: 227415.0000 - false_positives: 34.0000 - false_negatives: 182.0000 - accuracy: 0.9991 - val_loss: 0.0031 - val_auc: 0.9428 - val_precision: 0.8769 - val_recall: 0.7215 - val_true_positives: 57.0000 - val_true_negatives: 45482.0000 - val_false_positives: 8.0000 - val_false_negatives: 22.0000 - val_accuracy: 0.9993
# Epoch 15/20
# 7121/7121 [==============================] - 63s 9ms/step - loss: 0.0051 - auc: 0.8893 - precision: 0.8532 - recall: 0.5429 - true_positives: 215.0000 - true_negatives: 227412.0000 - false_positives: 37.0000 - false_negatives: 181.0000 - accuracy: 0.9990 - val_loss: 0.0031 - val_auc: 0.9428 - val_precision: 0.8806 - val_recall: 0.7468 - val_true_positives: 59.0000 - val_true_negatives: 45482.0000 - val_false_positives: 8.0000 - val_false_negatives: 20.0000 - val_accuracy: 0.9994
# Epoch 16/20
# 7121/7121 [==============================] - 64s 9ms/step - loss: 0.0050 - auc: 0.8944 - precision: 0.8582 - recall: 0.5657 - true_positives: 224.0000 - true_negatives: 227412.0000 - false_positives: 37.0000 - false_negatives: 172.0000 - accuracy: 0.9991 - val_loss: 0.0031 - val_auc: 0.9491 - val_precision: 0.8788 - val_recall: 0.7342 - val_true_positives: 58.0000 - val_true_negatives: 45482.0000 - val_false_positives: 8.0000 - val_false_negatives: 21.0000 - val_accuracy: 0.9994
# Epoch 17/20
# 7121/7121 [==============================] - 64s 9ms/step - loss: 0.0051 - auc: 0.8943 - precision: 0.8589 - recall: 0.5379 - true_positives: 213.0000 - true_negatives: 227414.0000 - false_positives: 35.0000 - false_negatives: 183.0000 - accuracy: 0.9990 - val_loss: 0.0031 - val_auc: 0.9554 - val_precision: 0.8824 - val_recall: 0.7595 - val_true_positives: 60.0000 - val_true_negatives: 45482.0000 - val_false_positives: 8.0000 - val_false_negatives: 19.0000 - val_accuracy: 0.9994
# Epoch 18/20
# 7121/7121 [==============================] - 64s 9ms/step - loss: 0.0051 - auc: 0.8829 - precision: 0.8706 - recall: 0.5606 - true_positives: 222.0000 - true_negatives: 227416.0000 - false_positives: 33.0000 - false_negatives: 174.0000 - accuracy: 0.9991 - val_loss: 0.0032 - val_auc: 0.9491 - val_precision: 0.8772 - val_recall: 0.6329 - val_true_positives: 50.0000 - val_true_negatives: 45483.0000 - val_false_positives: 7.0000 - val_false_negatives: 29.0000 - val_accuracy: 0.9992
# Epoch 19/20
# 7121/7121 [==============================] - 64s 9ms/step - loss: 0.0048 - auc: 0.8980 - precision: 0.8769 - recall: 0.5758 - true_positives: 228.0000 - true_negatives: 227417.0000 - false_positives: 32.0000 - false_negatives: 168.0000 - accuracy: 0.9991 - val_loss: 0.0030 - val_auc: 0.9554 - val_precision: 0.8857 - val_recall: 0.7848 - val_true_positives: 62.0000 - val_true_negatives: 45482.0000 - val_false_positives: 8.0000 - val_false_negatives: 17.0000 - val_accuracy: 0.9995
# Epoch 20/20
# 7121/7121 [==============================] - 64s 9ms/step - loss: 0.0053 - auc: 0.8752 - precision: 0.8537 - recall: 0.5303 - true_positives: 210.0000 - true_negatives: 227413.0000 - false_positives: 36.0000 - false_negatives: 186.0000 - accuracy: 0.9990 - val_loss: 0.0031 - val_auc: 0.9491 - val_precision: 0.8871 - val_recall: 0.6962 - val_true_positives: 55.0000 - val_true_negatives: 45483.0000 - val_false_positives: 7.0000 - val_false_negatives: 24.0000 - val_accuracy: 0.9993

# %%
plt.plot(history_0.history['loss'])
plt.plot(history_0.history['val_loss'])
plt.show()

# %%
result_matrix1=m.evaluate(x_test,y_test,return_dict=True)
result_matrix1=pd.DataFrame(result_matrix1,index=[0])
result_matrix1
# Out:
# 1425/1425 [==============================] - 11s 8ms/step - loss: 0.0031 - auc: 0.9491 - precision: 0.8871 - recall: 0.6962 - true_positives: 55.0000 - true_negatives: 45483.0000 - false_positives: 7.0000 - false_negatives: 24.0000 - accuracy: 0.9993
#        loss       auc  precision  ...  false_positives  false_negatives  accuracy
# 0  0.003071  0.949132   0.887097  ...              7.0             24.0   0.99932
#
# [1 rows x 9 columns]

# %% [markdown]
# # Train the model with class weights

# %%
m1=probitmodel()
classweight_0=len(x)/(2*len(y[y==0]))
classweight_1=len(x)/(2*len(y[y==1]))
classweight={0:classweight_0,1:classweight_1}
history_1=m1.fit(x_train,y_train,validation_data=[x_test,y_test],callbacks=callback,epochs=20,class_weight=classweight)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 8)                 240
#
#  dropout_1 (Dropout)         (None, 8)                 0
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 249
# Trainable params: 249
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 7121/7121 [==============================] - 68s 9ms/step - loss: 0.6847 - auc: 0.5298 - precision: 0.0019 - recall: 0.4495 - true_positives: 178.0000 - true_negatives: 134090.0000 - false_positives: 93359.0000 - false_negatives: 218.0000 - accuracy: 0.5893 - val_loss: 0.6689 - val_auc: 0.9249 - val_precision: 0.7303 - val_recall: 0.8228 - val_true_positives: 65.0000 - val_true_negatives: 45466.0000 - val_false_positives: 24.0000 - val_false_negatives: 14.0000 - val_accuracy: 0.9992
# Epoch 2/20
# 7121/7121 [==============================] - 64s 9ms/step - loss: 0.4517 - auc: 0.8397 - precision: 0.7615 - recall: 0.6288 - true_positives: 249.0000 - true_negatives: 227371.0000 - false_positives: 78.0000 - false_negatives: 147.0000 - accuracy: 0.9990 - val_loss: 0.3738 - val_auc: 0.9321 - val_precision: 0.7816 - val_recall: 0.8608 - val_true_positives: 68.0000 - val_true_negatives: 45471.0000 - val_false_positives: 19.0000 - val_false_negatives: 11.0000 - val_accuracy: 0.9993
# Epoch 3/20
# 7121/7121 [==============================] - 67s 9ms/step - loss: 0.3561 - auc: 0.8659 - precision: 0.7527 - recall: 0.7146 - true_positives: 283.0000 - true_negatives: 227356.0000 - false_positives: 93.0000 - false_negatives: 113.0000 - accuracy: 0.9991 - val_loss: 0.2913 - val_auc: 0.9358 - val_precision: 0.7727 - val_recall: 0.8608 - val_true_positives: 68.0000 - val_true_negatives: 45470.0000 - val_false_positives: 20.0000 - val_false_negatives: 11.0000 - val_accuracy: 0.9993
# Epoch 4/20
# 7121/7121 [==============================] - 66s 9ms/step - loss: 0.3332 - auc: 0.8915 - precision: 0.5103 - recall: 0.7475 - true_positives: 296.0000 - true_negatives: 227165.0000 - false_positives: 284.0000 - false_negatives: 100.0000 - accuracy: 0.9983 - val_loss: 0.2505 - val_auc: 0.9550 - val_precision: 0.3608 - val_recall: 0.8861 - val_true_positives: 70.0000 - val_true_negatives: 45366.0000 - val_false_positives: 124.0000 - val_false_negatives: 9.0000 - val_accuracy: 0.9971
# Epoch 5/20
# 7121/7121 [==============================] - 67s 9ms/step - loss: 0.3240 - auc: 0.8842 - precision: 0.2220 - recall: 0.7551 - true_positives: 299.0000 - true_negatives: 226401.0000 - false_positives: 1048.0000 - false_negatives: 97.0000 - accuracy: 0.9950 - val_loss: 0.2344 - val_auc: 0.9555 - val_precision: 0.2152 - val_recall: 0.8987 - val_true_positives: 71.0000 - val_true_negatives: 45231.0000 - val_false_positives: 259.0000 - val_false_negatives: 8.0000 - val_accuracy: 0.9941
# Epoch 6/20
# 7121/7121 [==============================] - 65s 9ms/step - loss: 0.3092 - auc: 0.9009 - precision: 0.2057 - recall: 0.7677 - true_positives: 304.0000 - true_negatives: 226275.0000 - false_positives: 1174.0000 - false_negatives: 92.0000 - accuracy: 0.9944 - val_loss: 0.2123 - val_auc: 0.9572 - val_precision: 0.2958 - val_recall: 0.8987 - val_true_positives: 71.0000 - val_true_negatives: 45321.0000 - val_false_positives: 169.0000 - val_false_negatives: 8.0000 - val_accuracy: 0.9961
# Epoch 7/20
# 7121/7121 [==============================] - 65s 9ms/step - loss: 0.2849 - auc: 0.9142 - precision: 0.1864 - recall: 0.7929 - true_positives: 314.0000 - true_negatives: 226078.0000 - false_positives: 1371.0000 - false_negatives: 82.0000 - accuracy: 0.9936 - val_loss: 0.1874 - val_auc: 0.9613 - val_precision: 0.2391 - val_recall: 0.8987 - val_true_positives: 71.0000 - val_true_negatives: 45264.0000 - val_false_positives: 226.0000 - val_false_negatives: 8.0000 - val_accuracy: 0.9949
# Epoch 8/20
# 7121/7121 [==============================] - 66s 9ms/step - loss: 0.3028 - auc: 0.9045 - precision: 0.1850 - recall: 0.7702 - true_positives: 305.0000 - true_negatives: 226105.0000 - false_positives: 1344.0000 - false_negatives: 91.0000 - accuracy: 0.9937 - val_loss: 0.2034 - val_auc: 0.9649 - val_precision: 0.1862 - val_recall: 0.9241 - val_true_positives: 73.0000 - val_true_negatives: 45171.0000 - val_false_positives: 319.0000 - val_false_negatives: 6.0000 - val_accuracy: 0.9929
# Epoch 9/20
# 7121/7121 [==============================] - 65s 9ms/step - loss: 0.3057 - auc: 0.9103 - precision: 0.1658 - recall: 0.7500 - true_positives: 297.0000 - true_negatives: 225955.0000 - false_positives: 1494.0000 - false_negatives: 99.0000 - accuracy: 0.9930 - val_loss: 0.2009 - val_auc: 0.9666 - val_precision: 0.1952 - val_recall: 0.9241 - val_true_positives: 73.0000 - val_true_negatives: 45189.0000 - val_false_positives: 301.0000 - val_false_negatives: 6.0000 - val_accuracy: 0.9933
# Epoch 10/20
# 7121/7121 [==============================] - 65s 9ms/step - loss: 0.2953 - auc: 0.9165 - precision: 0.1485 - recall: 0.7652 - true_positives: 303.0000 - true_negatives: 225712.0000 - false_positives: 1737.0000 - false_negatives: 93.0000 - accuracy: 0.9920 - val_loss: 0.1892 - val_auc: 0.9682 - val_precision: 0.2086 - val_recall: 0.9241 - val_true_positives: 73.0000 - val_true_negatives: 45213.0000 - val_false_positives: 277.0000 - val_false_negatives: 6.0000 - val_accuracy: 0.9938
# Epoch 11/20
# 7121/7121 [==============================] - 64s 9ms/step - loss: 0.2877 - auc: 0.9241 - precision: 0.1547 - recall: 0.7626 - true_positives: 302.0000 - true_negatives: 225799.0000 - false_positives: 1650.0000 - false_negatives: 94.0000 - accuracy: 0.9923 - val_loss: 0.1770 - val_auc: 0.9670 - val_precision: 0.2179 - val_recall: 0.9241 - val_true_positives: 73.0000 - val_true_negatives: 45228.0000 - val_false_positives: 262.0000 - val_false_negatives: 6.0000 - val_accuracy: 0.9941
# Epoch 12/20
# 7121/7121 [==============================] - 64s 9ms/step - loss: 0.2790 - auc: 0.9266 - precision: 0.1641 - recall: 0.7929 - true_positives: 314.0000 - true_negatives: 225849.0000 - false_positives: 1600.0000 - false_negatives: 82.0000 - accuracy: 0.9926 - val_loss: 0.1647 - val_auc: 0.9672 - val_precision: 0.2135 - val_recall: 0.9241 - val_true_positives: 73.0000 - val_true_negatives: 45221.0000 - val_false_positives: 269.0000 - val_false_negatives: 6.0000 - val_accuracy: 0.9940
# Epoch 13/20
# 7121/7121 [==============================] - 64s 9ms/step - loss: 0.2724 - auc: 0.9286 - precision: 0.1503 - recall: 0.7828 - true_positives: 310.0000 - true_negatives: 225696.0000 - false_positives: 1753.0000 - false_negatives: 86.0000 - accuracy: 0.9919 - val_loss: 0.1669 - val_auc: 0.9688 - val_precision: 0.1886 - val_recall: 0.9241 - val_true_positives: 73.0000 - val_true_negatives: 45176.0000 - val_false_positives: 314.0000 - val_false_negatives: 6.0000 - val_accuracy: 0.9930
# Epoch 14/20
# 7121/7121 [==============================] - 64s 9ms/step - loss: 0.2530 - auc: 0.9366 - precision: 0.1581 - recall: 0.7980 - true_positives: 316.0000 - true_negatives: 225766.0000 - false_positives: 1683.0000 - false_negatives: 80.0000 - accuracy: 0.9923 - val_loss: 0.1596 - val_auc: 0.9660 - val_precision: 0.2033 - val_recall: 0.9241 - val_true_positives: 73.0000 - val_true_negatives: 45204.0000 - val_false_positives: 286.0000 - val_false_negatives: 6.0000 - val_accuracy: 0.9936
# Epoch 15/20
# 7121/7121 [==============================] - 64s 9ms/step - loss: 0.2499 - auc: 0.9391 - precision: 0.1414 - recall: 0.8106 - true_positives: 321.0000 - true_negatives: 225500.0000 - false_positives: 1949.0000 - false_negatives: 75.0000 - accuracy: 0.9911 - val_loss: 0.1563 - val_auc: 0.9678 - val_precision: 0.2110 - val_recall: 0.9241 - val_true_positives: 73.0000 - val_true_negatives: 45217.0000 - val_false_positives: 273.0000 - val_false_negatives: 6.0000 - val_accuracy: 0.9939
# Epoch 16/20
# 7121/7121 [==============================] - 64s 9ms/step - loss: 0.2574 - auc: 0.9378 - precision: 0.1396 - recall: 0.7904 - true_positives: 313.0000 - true_negatives: 225520.0000 - false_positives: 1929.0000 - false_negatives: 83.0000 - accuracy: 0.9912 - val_loss: 0.1564 - val_auc: 0.9678 - val_precision: 0.1714 - val_recall: 0.9241 - val_true_positives: 73.0000 - val_true_negatives: 45137.0000 - val_false_positives: 353.0000 - val_false_negatives: 6.0000 - val_accuracy: 0.9921
# Epoch 17/20
# 7121/7121 [==============================] - 64s 9ms/step - loss: 0.2491 - auc: 0.9478 - precision: 0.1287 - recall: 0.7879 - true_positives: 312.0000 - true_negatives: 225336.0000 - false_positives: 2113.0000 - false_negatives: 84.0000 - accuracy: 0.9904 - val_loss: 0.1520 - val_auc: 0.9680 - val_precision: 0.1834 - val_recall: 0.9241 - val_true_positives: 73.0000 - val_true_negatives: 45165.0000 - val_false_positives: 325.0000 - val_false_negatives: 6.0000 - val_accuracy: 0.9927
# Epoch 18/20
# 7121/7121 [==============================] - 64s 9ms/step - loss: 0.2430 - auc: 0.9501 - precision: 0.1355 - recall: 0.8207 - true_positives: 325.0000 - true_negatives: 225376.0000 - false_positives: 2073.0000 - false_negatives: 71.0000 - accuracy: 0.9906 - val_loss: 0.1486 - val_auc: 0.9685 - val_precision: 0.1527 - val_recall: 0.9241 - val_true_positives: 73.0000 - val_true_negatives: 45085.0000 - val_false_positives: 405.0000 - val_false_negatives: 6.0000 - val_accuracy: 0.9910
# Epoch 19/20
# 7121/7121 [==============================] - 66s 9ms/step - loss: 0.2410 - auc: 0.9501 - precision: 0.1282 - recall: 0.8056 - true_positives: 319.0000 - true_negatives: 225280.0000 - false_positives: 2169.0000 - false_negatives: 77.0000 - accuracy: 0.9901 - val_loss: 0.1353 - val_auc: 0.9695 - val_precision: 0.2017 - val_recall: 0.9241 - val_true_positives: 73.0000 - val_true_negatives: 45201.0000 - val_false_positives: 289.0000 - val_false_negatives: 6.0000 - val_accuracy: 0.9935
# Epoch 20/20
# 7121/7121 [==============================] - 63s 9ms/step - loss: 0.2498 - auc: 0.9483 - precision: 0.1349 - recall: 0.7803 - true_positives: 309.0000 - true_negatives: 225468.0000 - false_positives: 1981.0000 - false_negatives: 87.0000 - accuracy: 0.9909 - val_loss: 0.1400 - val_auc: 0.9682 - val_precision: 0.1759 - val_recall: 0.9241 - val_true_positives: 73.0000 - val_true_negatives: 45148.0000 - val_false_positives: 342.0000 - val_false_negatives: 6.0000 - val_accuracy: 0.9924

# %%
plt.plot(history_1.history['loss'])
plt.plot(history_1.history['val_loss'])
plt.show()

# %%
result_matrix2=m1.evaluate(x_test,y_test,return_dict=True)
result_matrix2=pd.DataFrame(result_matrix1,index=[0])
result_matrix2
# Out:
# 1425/1425 [==============================] - 10s 7ms/step - loss: 0.1400 - auc: 0.9682 - precision: 0.1759 - recall: 0.9241 - true_positives: 73.0000 - true_negatives: 45148.0000 - false_positives: 342.0000 - false_negatives: 6.0000 - accuracy: 0.9924
#        loss       auc  precision  ...  false_positives  false_negatives  accuracy
# 0  0.003071  0.949132   0.887097  ...              7.0             24.0   0.99932
#
# [1 rows x 9 columns]

# %% [markdown]
# # Oversampling the minority class

# %% [markdown]
# oversampling the minority class using SMOTE function that uses KNN approach

# %%
sampler=SMOTE(sampling_strategy='minority')
x_resampled,y_resampled=sampler.fit_resample(x_train,y_train)

# %%
m2=probitmodel()
callback=tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5,restore_best_weights=1)
m2.evaluate(x_test[:10],y_test[:10])
history_2=m2.fit(x_resampled,y_resampled,validation_data=[x_test,y_test],callbacks=callback,epochs=20,class_weight=classweight)

# %%
result_matrix3=m2.evaluate(x_test,y_test,return_dict=True)
result_matrix3=pd.DataFrame(result_matrix3,index=[0])
result_matrix3
# Out:
# 1425/1425 [==============================] - 11s 8ms/step - loss: 0.0720 - auc: 0.9870 - precision: 0.0523 - recall: 0.9494 - true_positives: 75.0000 - true_negatives: 44131.0000 - false_positives: 1359.0000 - false_negatives: 4.0000 - accuracy: 0.9701
#        loss       auc  precision  ...  false_positives  false_negatives  accuracy
# 0  0.071956  0.987031   0.052301  ...           1359.0              4.0  0.970089
#
# [1 rows x 9 columns]
